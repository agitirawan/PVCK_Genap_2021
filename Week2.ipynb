# %% [markdown]
# <a href="https://colab.research.google.com/github/agitirawan/PVCK_Genap_2021/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/My Drive/PCVK_MM/Images/kitten01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap = 'gray')

# %%
plt.imshow(img_gray, cmap = 'magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB),0)
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],
                     [200,200],
                     [400,300],
                     [200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# Pertayaan
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
# jawaban
# Jawab : Gambar yang ditampikan tanpa matplotlib akan hanya muncul gambar saja, dan jika gambar ditampilkan dengan library matplotlib maka gambar akan dimunculkan bersama sumbu dan sumbu y sebagai penanda.
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dan int32?
# jawaban : Perbedaannya hanya ukuran filenya saja sehingga akan mempengaruhi kapasistas penyimpanannya. Yang mana int16 bernilai (-32,768 hingga +32767) sedangkan int 32 bernilai (-2,147,483,648 hingga +2,147,483,647).
# 3. Jelaskan tentang angka-angka yang terdapat pada reshape((-1,1,2))
# jawaban: Angka tersebut merupakan nilai dari R, G, B.
# 4. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode berikut
# jawaban :  Untuk menampilkan gambar pada google collab kita perlu menggunakan patches.
# 5. Apakah kegunaan “skimage impot io” pada potongan kode soal nomor 4
# jawaban : Mengimport library skimage dan mengimport io yang mana untuk menload gambar, read dan write gambar.

# %% [markdown]
# Tugas
#
# 1. Tampilkan image dalam channel Red-Green dan Green-Blue saja!
# jawaban :

# %%
img_rg = img.copy()
img_rg[:,:,2] = 0
plt.imshow(img_rg)

# %% [markdown]
# 2. Tampilkan image baris ke 10-100, kolom 10-100!
# jawaban :

# %%
img_gb = img
img_gb[:,:,0] = 0
plt.imshow(img_gb)

# %% [markdown]
# 3. Tampilkan image baris ke 5-30, semua kolom, channel Green saja!
# jawaban :

# %%
img_k = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg')
plt.imshow(img_k[10:100,10:100])

# %% [markdown]
# 4. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random!
# jawaban:

# %%
img_k = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg')
plt.imshow(img_k[5:30], cmap='Greens')

# %% [markdown]
# 5. Tampilkan image dengan posisi terbalik! Berdasarkan praktikum
# jawaban:

# %%
img_k = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img_k, pt1=(300,300), pt2=(40,170), color=(0,255,255), thickness=10)
cv.rectangle(img_k, pt1=(900,100), pt2=(600,200), color=(0,255,0),thickness=10)
cv.rectangle(img_k, pt1=(400,400), pt2=(900,300), color=(255,255,255),thickness=10)
cv.rectangle(img_k, pt1=(100,900), pt2=(300,400), color=(255,0,0),thickness=10)
cv.rectangle(img_k, pt1=(900,700), pt2=(600,550), color=(0,0,255),thickness=10)
plt.imshow(img_k)

# %%
img_t = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111)
ax.imshow(img_t)

# %% [markdown]
# 6. Buat rectangle dan circle pada bagian wajah dari image kitten!
# jawaban:

# %%
img_t6 = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg')

cv.rectangle(img_t6,pt1=(300,100),pt2=(500,300),color=(0,255,0),thickness=5)
cv.circle(img_t6,center=(400,200),radius=65,color=(255,0,0),thickness=5)
plt.imshow(img_t6)

# %% [markdown]
# 7. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten01.jpg!
# jawaban :

# %%
cv.rectangle(img_t6,pt1=(100,500),pt2=(10,600),color=(0,255,0),thickness=10)
plt.imshow(img_t6)
